# %% [markdown]
# # Self-Driving Car Engineer Nanodegree
#
# ## Deep Learning
#
# ## Project: Build a Traffic Sign Recognition Classifier
#
# In this notebook, a template is provided for you to implement your functionality in stages, which is required to successfully complete this project. If additional code is required that cannot be included in the notebook, be sure that the Python code is successfully imported and included in your submission if necessary.
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there is a writeup to complete. The writeup should be completed in a separate file, which can be either a markdown file or a pdf document. There is a [write up template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) that can be used to guide the writing process. Completing the code template and writeup template will cover all of the [rubric points](https://review.udacity.com/#!/rubrics/481/view) for this project.
#
# The [rubric](https://review.udacity.com/#!/rubrics/481/view) contains "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. The stand out suggestions are optional. If you decide to pursue the "stand out suggestions", you can include the code in this Ipython notebook and also discuss the results in the writeup file.
#
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut. In addition, Markdown cells can be edited by typically double-clicking the cell to enter edit mode.

# %% [markdown]
# ---
# ## Step 0: Load The Data

# %%
# Load pickled data
import pickle

# TODO: Fill this in based on where you saved the training and testing data

training_file = '../data/train.p'
validation_file = '../data/valid.p'
testing_file = '../data/test.p'

with open(training_file, mode='rb') as f:
    train = pickle.load(f)
with open(validation_file, mode='rb') as f:
    valid = pickle.load(f)
with open(testing_file, mode='rb') as f:
    test = pickle.load(f)
    
X_train, y_train = train['features'], train['labels']
X_valid, y_valid = valid['features'], valid['labels']
X_test, y_test = test['features'], test['labels']

# %% [markdown]
# ---
#
# ## Step 1: Dataset Summary & Exploration
#
# The pickled data is a dictionary with 4 key/value pairs:
#
# - `'features'` is a 4D array containing raw pixel data of the traffic sign images, (num examples, width, height, channels).
# - `'labels'` is a 1D array containing the label/class id of the traffic sign. The file `signnames.csv` contains id -> name mappings for each id.
# - `'sizes'` is a list containing tuples, (width, height) representing the original width and height the image.
# - `'coords'` is a list containing tuples, (x1, y1, x2, y2) representing coordinates of a bounding box around the sign in the image. **THESE COORDINATES ASSUME THE ORIGINAL IMAGE. THE PICKLED DATA CONTAINS RESIZED VERSIONS (32 by 32) OF THESE IMAGES**
#
# Complete the basic data summary below. Use python, numpy and/or pandas methods to calculate the data summary rather than hard coding the results. For example, the [pandas shape method](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.shape.html) might be useful for calculating some of the summary results.

# %% [markdown]
# ### Provide a Basic Summary of the Data Set Using Python, Numpy and/or Pandas

# %%
### Replace each question mark with the appropriate value. 
### Use python, pandas or numpy methods rather than hard coding the results

# TODO: Number of training examples
n_train = len(X_train)

# TODO: Number of validation examples
n_validation = len(X_valid)

# TODO: Number of testing examples.
n_test = len(X_test)

# TODO: What's the shape of an traffic sign image?
image_shape = X_train[0].shape

# TODO: How many unique classes/labels there are in the dataset.
n_classes = 43

print("Number of training examples =", n_train)
print("Number of testing examples =", n_test)
print("Number of valid examples =", n_validation , y_valid.shape)
print("Image data shape =", image_shape)
print("Number of classes =", n_classes)
# Out:
# Number of training examples = 34799
# Number of testing examples = 12630
# Number of valid examples = 4410 (4410,)
# Image data shape = (32, 32, 3)
# Number of classes = 43

# %% [markdown]
# ### Include an exploratory visualization of the dataset

# %% [markdown]
# Visualize the German Traffic Signs Dataset using the pickled file(s). This is open ended, suggestions include: plotting traffic sign images, plotting the count of each sign, etc.
#
# The [Matplotlib](http://matplotlib.org/) [examples](http://matplotlib.org/examples/index.html) and [gallery](http://matplotlib.org/gallery.html) pages are a great resource for doing visualizations in Python.
#
# **NOTE:** It's recommended you start with something simple first. If you wish to do more, come back to it after you've completed the rest of the sections. It can be interesting to look at the distribution of classes in the training, validation and test set. Is the distribution the same? Are there more examples of some classes than others?

# %%
### Data exploration visualization code goes here.
### Feel free to use as many code cells as needed.
import matplotlib.pyplot as plt
# Visualizations will be shown in the notebook.
# %matplotlib inline

# %%
# 数据可视化
import random
import numpy as np

index = random.randint(0 , len(X_train))
image = X_train[index].squeeze()

#print(X_train[5].shape)
plt.figure(figsize = (1 , 1))
plt.imshow(image , cmap = "gray")
print(y_train[index])
# Out:
# 11

# %% [markdown]
# ----
#
# ## Step 2: Design and Test a Model Architecture
#
# Design and implement a deep learning model that learns to recognize traffic signs. Train and test your model on the [German Traffic Sign Dataset](http://benchmark.ini.rub.de/?section=gtsrb&subsection=dataset).
#
# The LeNet-5 implementation shown in the [classroom](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) at the end of the CNN lesson is a solid starting point. You'll have to change the number of classes and possibly the preprocessing, but aside from that it's plug and play!
#
# With the LeNet-5 solution from the lecture, you should expect a validation set accuracy of about 0.89. To meet specifications, the validation set accuracy will need to be at least 0.93. It is possible to get an even higher accuracy, but 0.93 is the minimum for a successful project submission.
#
# There are various aspects to consider when thinking about this problem:
#
# - Neural network architecture (is the network over or underfitting?)
# - Play around preprocessing techniques (normalization, rgb to grayscale, etc)
# - Number of examples per label (some have more than others).
# - Generate fake data.
#
# Here is an example of a [published baseline model on this problem](http://yann.lecun.com/exdb/publis/pdf/sermanet-ijcnn-11.pdf). It's not required to be familiar with the approach used in the paper but, it's good practice to try to read papers like these.

# %% [markdown]
# ### Pre-process the Data Set (normalization, grayscale, etc.)

# %% [markdown]
# Minimally, the image data should be normalized so that the data has mean zero and equal variance. For image data, `(pixel - 128)/ 128` is a quick way to approximately normalize the data and can be used in this project.
#
# Other pre-processing steps are optional. You can try different techniques to see if it improves performance.
#
# Use the code cell (or multiple code cells, if necessary) to implement the first step of your project.

# %%
import tensorflow as tf
from sklearn.utils import shuffle

# %%
# 定义全局参数
EPOCHS = 500
BATCH_SIZE = 128

rate = 0.0001

# %%
### Preprocess the data here. It is required to normalize the data. Other preprocessing steps could include 
### converting to grayscale, etc.
### Feel free to use as many code cells as needed.

def data_preprocess(x , y):
    x = (x - 128) / 128
    return x , y
    


X_train , y_train = data_preprocess(X_train , y_train)
X_test , y_test = data_preprocess(X_test , y_test)
X_valid , y_valid = data_preprocess(X_valid , y_valid)

# %% [markdown]
# ### Model Architecture

# %%
### model two
### Define your architecture here.
### Feel free to use as many code cells as needed.
from tensorflow.contrib.layers import flatten

def LeNet(x):    
    # Arguments used for tf.truncated_normal, randomly defines variables for the weights and biases for each layer
    mu = 0
    sigma = 0.05
    
    # SOLUTION: Layer 1: Convolutional. Input = 32x32x3. Output = 30x30x16.
    conv1_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 3, 16), mean = mu, stddev = sigma))
    conv1_b = tf.Variable(tf.zeros(16))
    conv1   = tf.nn.conv2d(x, conv1_W, strides=[1, 1, 1, 1], padding='VALID') + conv1_b

    # SOLUTION: Activation.
    conv1 = tf.nn.relu(conv1)
    conv1 = tf.nn.dropout(conv1 , tf.constant(0.5))

    # SOLUTION: Pooling. Input = 30x30x16. Output = 15x15x16.
    conv1 = tf.nn.max_pool(conv1, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Layer 2: Convolutional. Output = 13x13x32.
    conv2_W = tf.Variable(tf.truncated_normal(shape=(3, 3, 16, 32), mean = mu, stddev = sigma))
    conv2_b = tf.Variable(tf.zeros(32))
    conv2   = tf.nn.conv2d(conv1, conv2_W, strides=[1, 1, 1, 1], padding='VALID') + conv2_b
    
    # SOLUTION: Activation.
    conv2 = tf.nn.relu(conv2)
    conv2 = tf.nn.dropout(conv2 , tf.constant(0.5))

    # SOLUTION: Pooling. Input = 13x13x32. Output = 6x6x32
    conv2 = tf.nn.max_pool(conv2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='VALID')

    # SOLUTION: Flatten. Input = 6x6x32.
    fc0   = flatten(conv2)
    
    # SOLUTION: Layer 3: Fully Connected. Input = . Output = 400.
    fc1_W = tf.Variable(tf.truncated_normal(shape=(6*6*32, 400), mean = mu, stddev = sigma))
    fc1_b = tf.Variable(tf.zeros(400))
    fc1   = tf.matmul(fc0, fc1_W) + fc1_b
    
    # SOLUTION: Activation.
    fc1    = tf.nn.relu(fc1)
    fc1    = tf.nn.dropout(fc1 , tf.constant(0.5))

    # SOLUTION: Layer 4: Fully Connected. Input = 300. Output = 120.
    fc2_W  = tf.Variable(tf.truncated_normal(shape=(400, 200), mean = mu, stddev = sigma))
    fc2_b  = tf.Variable(tf.zeros(200))
    fc2    = tf.matmul(fc1, fc2_W) + fc2_b
    
    # SOLUTION: Activation.
    fc2    = tf.nn.relu(fc2)
    fc2    = tf.nn.dropout(fc2 , tf.constant(0.5))

    # SOLUTION: Layer 5: Fully Connected. Input = 200. Output = 43.
    fc3_W  = tf.Variable(tf.truncated_normal(shape=(200, 43), mean = mu, stddev = sigma))
    fc3_b  = tf.Variable(tf.zeros(43))
    logits = tf.matmul(fc2, fc3_W) + fc3_b
    
    return logits

# %% [markdown]
# ### Train, Validate and Test the Model

# %% [markdown]
# A validation set can be used to assess how well the model is performing. A low accuracy on the training and validation
# sets imply underfitting. A high accuracy on the training set but low accuracy on the validation set implies overfitting.

# %%
### Train your model here.
### Calculate and report the accuracy on the training and validation set.
### Once a final model architecture is selected, 
### the accuracy on the test set should be calculated and reported as well.
### Feel free to use as many code cells as needed.
x = tf.placeholder(tf.float32, (None, 32, 32, 3))
y = tf.placeholder(tf.int32, (None))
one_hot_y = tf.one_hot(y, 43)

logits = LeNet(x)
cross_entropy = tf.nn.softmax_cross_entropy_with_logits(labels=one_hot_y, logits=logits)
loss_operation = tf.reduce_mean(cross_entropy)
optimizer = tf.train.AdamOptimizer(learning_rate = rate)
training_operation = optimizer.minimize(loss_operation)

# %%
correct_prediction = tf.equal(tf.argmax(logits, 1), tf.argmax(one_hot_y, 1))
accuracy_operation = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
saver = tf.train.Saver()

def evaluate(X_data, y_data):
    num_examples = len(X_data)
    total_accuracy = 0
    sess = tf.get_default_session()
    for offset in range(0, num_examples, BATCH_SIZE):
        batch_x, batch_y = X_data[offset:offset+BATCH_SIZE], y_data[offset:offset+BATCH_SIZE]
        accuracy = sess.run(accuracy_operation, feed_dict={x: batch_x, y: batch_y})
        total_accuracy += (accuracy * len(batch_x))
    return total_accuracy / num_examples

# %%
with tf.Session() as sess:
    #sess.run(tf.global_variables_initializer())
    saver.restore(sess, tf.train.latest_checkpoint('.'))
    num_examples = len(X_train)
    
    print("Training...")
    print()
    for i in range(EPOCHS):
        X_train, y_train = shuffle(X_train, y_train)
        for offset in range(0, num_examples, BATCH_SIZE):
            end = offset + BATCH_SIZE
            batch_x, batch_y = X_train[offset:end], y_train[offset:end]
            sess.run(training_operation, feed_dict={x: batch_x, y: batch_y})
            
        validation_accuracy = evaluate(X_valid, y_valid)
        print("EPOCH {} ...".format(i+1),"Validation Accuracy = {:.3f}".format(validation_accuracy))
        #print("Validation Accuracy = {:.3f}".format(validation_accuracy))
        #print()
        
    saver.save(sess, './lenet')
    print("Model saved")
# Out:
# INFO:tensorflow:Restoring parameters from ./lenet
# Training...
#
# EPOCH 1 ... Validation Accuracy = 0.859
# EPOCH 2 ... Validation Accuracy = 0.866
# EPOCH 3 ... Validation Accuracy = 0.865
# EPOCH 4 ... Validation Accuracy = 0.866
# EPOCH 5 ... Validation Accuracy = 0.864
# EPOCH 6 ... Validation Accuracy = 0.870
# EPOCH 7 ... Validation Accuracy = 0.870
# EPOCH 8 ... Validation Accuracy = 0.864
# EPOCH 9 ... Validation Accuracy = 0.869
# EPOCH 10 ... Validation Accuracy = 0.868
# EPOCH 11 ... Validation Accuracy = 0.858
# EPOCH 12 ... Validation Accuracy = 0.865
# EPOCH 13 ... Validation Accuracy = 0.865
# EPOCH 14 ... Validation Accuracy = 0.865
# EPOCH 15 ... Validation Accuracy = 0.867
# EPOCH 16 ... Validation Accuracy = 0.866
# EPOCH 17 ... Validation Accuracy = 0.860
# EPOCH 18 ... Validation Accuracy = 0.866
# EPOCH 19 ... Validation Accuracy = 0.870
# EPOCH 20 ... Validation Accuracy = 0.868
# EPOCH 21 ... Validation Accuracy = 0.862
# EPOCH 22 ... Validation Accuracy = 0.868
# EPOCH 23 ... Validation Accuracy = 0.866
# EPOCH 24 ... Validation Accuracy = 0.868
# EPOCH 25 ... Validation Accuracy = 0.866
# EPOCH 26 ... Validation Accuracy = 0.866
# EPOCH 27 ... Validation Accuracy = 0.863
# EPOCH 28 ... Validation Accuracy = 0.870
# EPOCH 29 ... Validation Accuracy = 0.870
# EPOCH 30 ... Validation Accuracy = 0.869
# EPOCH 31 ... Validation Accuracy = 0.868
# EPOCH 32 ... Validation Accuracy = 0.867
# EPOCH 33 ... Validation Accuracy = 0.868
# EPOCH 34 ... Validation Accuracy = 0.867
# EPOCH 35 ... Validation Accuracy = 0.868
# EPOCH 36 ... Validation Accuracy = 0.865
# EPOCH 37 ... Validation Accuracy = 0.867
# EPOCH 38 ... Validation Accuracy = 0.867
# EPOCH 39 ... Validation Accuracy = 0.873
# EPOCH 40 ... Validation Accuracy = 0.865
# EPOCH 41 ... Validation Accuracy = 0.869
# EPOCH 42 ... Validation Accuracy = 0.876
# EPOCH 43 ... Validation Accuracy = 0.863
# EPOCH 44 ... Validation Accuracy = 0.869
# EPOCH 45 ... Validation Accuracy = 0.861
# EPOCH 46 ... Validation Accuracy = 0.859
# EPOCH 47 ... Validation Accuracy = 0.864
# EPOCH 48 ... Validation Accuracy = 0.864
# EPOCH 49 ... Validation Accuracy = 0.865
# EPOCH 50 ... Validation Accuracy = 0.870
# EPOCH 51 ... Validation Accuracy = 0.865
# EPOCH 52 ... Validation Accuracy = 0.864
# EPOCH 53 ... Validation Accuracy = 0.870
# EPOCH 54 ... Validation Accuracy = 0.866
# EPOCH 55 ... Validation Accuracy = 0.865
# EPOCH 56 ... Validation Accuracy = 0.869
# EPOCH 57 ... Validation Accuracy = 0.868
# EPOCH 58 ... Validation Accuracy = 0.861
# EPOCH 59 ... Validation Accuracy = 0.863
# EPOCH 60 ... Validation Accuracy = 0.871
# EPOCH 61 ... Validation Accuracy = 0.865
# EPOCH 62 ... Validation Accuracy = 0.869
# EPOCH 63 ... Validation Accuracy = 0.870
# EPOCH 64 ... Validation Accuracy = 0.865
# EPOCH 65 ... Validation Accuracy = 0.865
# EPOCH 66 ... Validation Accuracy = 0.861
# EPOCH 67 ... Validation Accuracy = 0.869
# EPOCH 68 ... Validation Accuracy = 0.867
# EPOCH 69 ... Validation Accuracy = 0.877
# EPOCH 70 ... Validation Accuracy = 0.865
# EPOCH 71 ... Validation Accuracy = 0.871
# EPOCH 72 ... Validation Accuracy = 0.868
# EPOCH 73 ... Validation Accuracy = 0.865
# EPOCH 74 ... Validation Accuracy = 0.868
# EPOCH 75 ... Validation Accuracy = 0.868
# EPOCH 76 ... Validation Accuracy = 0.865
# EPOCH 77 ... Validation Accuracy = 0.871
# EPOCH 78 ... Validation Accuracy = 0.864
# EPOCH 79 ... Validation Accuracy = 0.867
# EPOCH 80 ... Validation Accuracy = 0.869
# EPOCH 81 ... Validation Accuracy = 0.866
# EPOCH 82 ... Validation Accuracy = 0.873
# EPOCH 83 ... Validation Accuracy = 0.868
# EPOCH 84 ... Validation Accuracy = 0.869
# EPOCH 85 ... Validation Accuracy = 0.869
# EPOCH 86 ... Validation Accuracy = 0.868
# EPOCH 87 ... Validation Accuracy = 0.868
# EPOCH 88 ... Validation Accuracy = 0.869
# EPOCH 89 ... Validation Accuracy = 0.869
# EPOCH 90 ... Validation Accuracy = 0.869
# EPOCH 91 ... Validation Accuracy = 0.869
# EPOCH 92 ... Validation Accuracy = 0.871
# EPOCH 93 ... Validation Accuracy = 0.871
# EPOCH 94 ... Validation Accuracy = 0.872
# EPOCH 95 ... Validation Accuracy = 0.865
# EPOCH 96 ... Validation Accuracy = 0.871
# EPOCH 97 ... Validation Accuracy = 0.870
# EPOCH 98 ... Validation Accuracy = 0.878
# EPOCH 99 ... Validation Accuracy = 0.869
# EPOCH 100 ... Validation Accuracy = 0.868
# EPOCH 101 ... Validation Accuracy = 0.866
# EPOCH 102 ... Validation Accuracy = 0.867
# EPOCH 103 ... Validation Accuracy = 0.872
# EPOCH 104 ... Validation Accuracy = 0.869
# EPOCH 105 ... Validation Accuracy = 0.868
# EPOCH 106 ... Validation Accuracy = 0.866
# EPOCH 107 ... Validation Accuracy = 0.866
# EPOCH 108 ... Validation Accuracy = 0.868
# EPOCH 109 ... Validation Accuracy = 0.871
# EPOCH 110 ... Validation Accuracy = 0.866
# EPOCH 111 ... Validation Accuracy = 0.870
# EPOCH 112 ... Validation Accuracy = 0.869
# EPOCH 113 ... Validation Accuracy = 0.867
# EPOCH 114 ... Validation Accuracy = 0.866
# EPOCH 115 ... Validation Accuracy = 0.877
# EPOCH 116 ... Validation Accuracy = 0.873
# EPOCH 117 ... Validation Accuracy = 0.871
# EPOCH 118 ... Validation Accuracy = 0.869
# EPOCH 119 ... Validation Accuracy = 0.866
# EPOCH 120 ... Validation Accuracy = 0.867
# EPOCH 121 ... Validation Accuracy = 0.862
# EPOCH 122 ... Validation Accuracy = 0.874
# EPOCH 123 ... Validation Accuracy = 0.866
# EPOCH 124 ... Validation Accuracy = 0.869
# EPOCH 125 ... Validation Accuracy = 0.869
# EPOCH 126 ... Validation Accuracy = 0.869
# EPOCH 127 ... Validation Accuracy = 0.870
# EPOCH 128 ... Validation Accuracy = 0.867
# EPOCH 129 ... Validation Accuracy = 0.868
# EPOCH 130 ... Validation Accuracy = 0.870
# EPOCH 131 ... Validation Accuracy = 0.867
# EPOCH 132 ... Validation Accuracy = 0.874
# EPOCH 133 ... Validation Accuracy = 0.873
# EPOCH 134 ... Validation Accuracy = 0.871
# EPOCH 135 ... Validation Accuracy = 0.871
# EPOCH 136 ... Validation Accuracy = 0.867
# EPOCH 137 ... Validation Accuracy = 0.872
# EPOCH 138 ... Validation Accuracy = 0.869
# EPOCH 139 ... Validation Accuracy = 0.871
# EPOCH 140 ... Validation Accuracy = 0.867
# EPOCH 141 ... Validation Accuracy = 0.866
# EPOCH 142 ... Validation Accuracy = 0.866
# EPOCH 143 ... Validation Accuracy = 0.864
# EPOCH 144 ... Validation Accuracy = 0.866
# EPOCH 145 ... Validation Accuracy = 0.866
# EPOCH 146 ... Validation Accuracy = 0.865
# EPOCH 147 ... Validation Accuracy = 0.872
# EPOCH 148 ... Validation Accuracy = 0.869
# EPOCH 149 ... Validation Accuracy = 0.865
# EPOCH 150 ... Validation Accuracy = 0.870
# EPOCH 151 ... Validation Accuracy = 0.870
# EPOCH 152 ... Validation Accuracy = 0.876
# EPOCH 153 ... Validation Accuracy = 0.866
# EPOCH 154 ... Validation Accuracy = 0.866
# EPOCH 155 ... Validation Accuracy = 0.868
# EPOCH 156 ... Validation Accuracy = 0.868
# EPOCH 157 ... Validation Accuracy = 0.872
# EPOCH 158 ... Validation Accuracy = 0.863
# EPOCH 159 ... Validation Accuracy = 0.868
# EPOCH 160 ... Validation Accuracy = 0.867
# EPOCH 161 ... Validation Accuracy = 0.873
# EPOCH 162 ... Validation Accuracy = 0.872
# EPOCH 163 ... Validation Accuracy = 0.859
# EPOCH 164 ... Validation Accuracy = 0.870
# EPOCH 165 ... Validation Accuracy = 0.863
# EPOCH 166 ... Validation Accuracy = 0.878
# EPOCH 167 ... Validation Accuracy = 0.871
# EPOCH 168 ... Validation Accuracy = 0.868
# EPOCH 169 ... Validation Accuracy = 0.869
# EPOCH 170 ... Validation Accuracy = 0.870
# EPOCH 171 ... Validation Accuracy = 0.868
# EPOCH 172 ... Validation Accuracy = 0.873
# EPOCH 173 ... Validation Accuracy = 0.869
# EPOCH 174 ... Validation Accuracy = 0.868
# EPOCH 175 ... Validation Accuracy = 0.869
# EPOCH 176 ... Validation Accuracy = 0.863
# EPOCH 177 ... Validation Accuracy = 0.871
# EPOCH 178 ... Validation Accuracy = 0.866
# EPOCH 179 ... Validation Accuracy = 0.868
# EPOCH 180 ... Validation Accuracy = 0.867
# EPOCH 181 ... Validation Accuracy = 0.873
# EPOCH 182 ... Validation Accuracy = 0.867
# EPOCH 183 ... Validation Accuracy = 0.865
# EPOCH 184 ... Validation Accuracy = 0.865
# EPOCH 185 ... Validation Accuracy = 0.871
# EPOCH 186 ... Validation Accuracy = 0.871
# EPOCH 187 ... Validation Accuracy = 0.871
# EPOCH 188 ... Validation Accuracy = 0.875
# EPOCH 189 ... Validation Accuracy = 0.870
# EPOCH 190 ... Validation Accuracy = 0.873
# EPOCH 191 ... Validation Accuracy = 0.871
# EPOCH 192 ... Validation Accuracy = 0.866
# EPOCH 193 ... Validation Accuracy = 0.866
# EPOCH 194 ... Validation Accuracy = 0.872
# EPOCH 195 ... Validation Accuracy = 0.871
# EPOCH 196 ... Validation Accuracy = 0.871
# EPOCH 197 ... Validation Accuracy = 0.871
# EPOCH 198 ... Validation Accuracy = 0.866
# EPOCH 199 ... Validation Accuracy = 0.870
# EPOCH 200 ... Validation Accuracy = 0.868
# EPOCH 201 ... Validation Accuracy = 0.870
# EPOCH 202 ... Validation Accuracy = 0.872
# EPOCH 203 ... Validation Accuracy = 0.873
# EPOCH 204 ... Validation Accuracy = 0.865
# EPOCH 205 ... Validation Accuracy = 0.870
# EPOCH 206 ... Validation Accuracy = 0.873
# EPOCH 207 ... Validation Accuracy = 0.870
# EPOCH 208 ... Validation Accuracy = 0.868
# EPOCH 209 ... Validation Accuracy = 0.865
# EPOCH 210 ... Validation Accuracy = 0.861
# EPOCH 211 ... Validation Accuracy = 0.867
# EPOCH 212 ... Validation Accuracy = 0.866
# EPOCH 213 ... Validation Accuracy = 0.871
# EPOCH 214 ... Validation Accuracy = 0.870
# EPOCH 215 ... Validation Accuracy = 0.865
# EPOCH 216 ... Validation Accuracy = 0.865
# EPOCH 217 ... Validation Accuracy = 0.870
# EPOCH 218 ... Validation Accuracy = 0.868
# EPOCH 219 ... Validation Accuracy = 0.871
# EPOCH 220 ... Validation Accuracy = 0.862
# EPOCH 221 ... Validation Accuracy = 0.865
# EPOCH 222 ... Validation Accuracy = 0.867
# EPOCH 223 ... Validation Accuracy = 0.870
# EPOCH 224 ... Validation Accuracy = 0.867
# EPOCH 225 ... Validation Accuracy = 0.868
# EPOCH 226 ... Validation Accuracy = 0.875
# EPOCH 227 ... Validation Accuracy = 0.866
# EPOCH 228 ... Validation Accuracy = 0.877
# EPOCH 229 ... Validation Accuracy = 0.874
# EPOCH 230 ... Validation Accuracy = 0.871
# EPOCH 231 ... Validation Accuracy = 0.864
# EPOCH 232 ... Validation Accuracy = 0.868
# EPOCH 233 ... Validation Accuracy = 0.870
# EPOCH 234 ... Validation Accuracy = 0.870
# EPOCH 235 ... Validation Accuracy = 0.868
# EPOCH 236 ... Validation Accuracy = 0.866
# EPOCH 237 ... Validation Accuracy = 0.862
# EPOCH 238 ... Validation Accuracy = 0.860
# EPOCH 239 ... Validation Accuracy = 0.868
# EPOCH 240 ... Validation Accuracy = 0.866
# EPOCH 241 ... Validation Accuracy = 0.869
# EPOCH 242 ... Validation Accuracy = 0.872
# EPOCH 243 ... Validation Accuracy = 0.864
# EPOCH 244 ... Validation Accuracy = 0.870
# EPOCH 245 ... Validation Accuracy = 0.867
# EPOCH 246 ... Validation Accuracy = 0.866
# EPOCH 247 ... Validation Accuracy = 0.870
# EPOCH 248 ... Validation Accuracy = 0.867
# EPOCH 249 ... Validation Accuracy = 0.866
# EPOCH 250 ... Validation Accuracy = 0.870
# EPOCH 251 ... Validation Accuracy = 0.866
# EPOCH 252 ... Validation Accuracy = 0.864
# EPOCH 253 ... Validation Accuracy = 0.867
# EPOCH 254 ... Validation Accuracy = 0.861
# EPOCH 255 ... Validation Accuracy = 0.867
# EPOCH 256 ... Validation Accuracy = 0.875
# EPOCH 257 ... Validation Accuracy = 0.860
# EPOCH 258 ... Validation Accuracy = 0.870
# EPOCH 259 ... Validation Accuracy = 0.873
# EPOCH 260 ... Validation Accuracy = 0.872
# EPOCH 261 ... Validation Accuracy = 0.866
# EPOCH 262 ... Validation Accuracy = 0.867
# EPOCH 263 ... Validation Accuracy = 0.870
# EPOCH 264 ... Validation Accuracy = 0.864
# EPOCH 265 ... Validation Accuracy = 0.868
# EPOCH 266 ... Validation Accuracy = 0.869
# EPOCH 267 ... Validation Accuracy = 0.870
# EPOCH 268 ... Validation Accuracy = 0.863
# EPOCH 269 ... Validation Accuracy = 0.866
# EPOCH 270 ... Validation Accuracy = 0.868
# EPOCH 271 ... Validation Accuracy = 0.869
# EPOCH 272 ... Validation Accuracy = 0.867
# EPOCH 273 ... Validation Accuracy = 0.868
# EPOCH 274 ... Validation Accuracy = 0.871
# EPOCH 275 ... Validation Accuracy = 0.864
# EPOCH 276 ... Validation Accuracy = 0.865
# EPOCH 277 ... Validation Accuracy = 0.865
# EPOCH 278 ... Validation Accuracy = 0.869
# EPOCH 279 ... Validation Accuracy = 0.871
# EPOCH 280 ... Validation Accuracy = 0.865
# EPOCH 281 ... Validation Accuracy = 0.866
# EPOCH 282 ... Validation Accuracy = 0.870
# EPOCH 283 ... Validation Accuracy = 0.870
# EPOCH 284 ... Validation Accuracy = 0.874
# EPOCH 285 ... Validation Accuracy = 0.867
# EPOCH 286 ... Validation Accuracy = 0.857
# EPOCH 287 ... Validation Accuracy = 0.871
# EPOCH 288 ... Validation Accuracy = 0.865
# EPOCH 289 ... Validation Accuracy = 0.864
# EPOCH 290 ... Validation Accuracy = 0.868
# EPOCH 291 ... Validation Accuracy = 0.870
# EPOCH 292 ... Validation Accuracy = 0.873
# EPOCH 293 ... Validation Accuracy = 0.869
# EPOCH 294 ... Validation Accuracy = 0.873
# EPOCH 295 ... Validation Accuracy = 0.865
# EPOCH 296 ... Validation Accuracy = 0.864
# EPOCH 297 ... Validation Accuracy = 0.869
# EPOCH 298 ... Validation Accuracy = 0.871
# EPOCH 299 ... Validation Accuracy = 0.866
# EPOCH 300 ... Validation Accuracy = 0.870
# EPOCH 301 ... Validation Accuracy = 0.864
# EPOCH 302 ... Validation Accuracy = 0.865
# EPOCH 303 ... Validation Accuracy = 0.872
# EPOCH 304 ... Validation Accuracy = 0.865
# EPOCH 305 ... Validation Accuracy = 0.872
# EPOCH 306 ... Validation Accuracy = 0.862
# EPOCH 307 ... Validation Accuracy = 0.868
# EPOCH 308 ... Validation Accuracy = 0.868
# EPOCH 309 ... Validation Accuracy = 0.858
# EPOCH 310 ... Validation Accuracy = 0.864
# EPOCH 311 ... Validation Accuracy = 0.866
# EPOCH 312 ... Validation Accuracy = 0.868
# EPOCH 313 ... Validation Accuracy = 0.877
# EPOCH 314 ... Validation Accuracy = 0.863
# EPOCH 315 ... Validation Accuracy = 0.867
# EPOCH 316 ... Validation Accuracy = 0.870
# EPOCH 317 ... Validation Accuracy = 0.869
# EPOCH 318 ... Validation Accuracy = 0.865
# EPOCH 319 ... Validation Accuracy = 0.868
# EPOCH 320 ... Validation Accuracy = 0.872
# EPOCH 321 ... Validation Accuracy = 0.866
# EPOCH 322 ... Validation Accuracy = 0.870
# EPOCH 323 ... Validation Accuracy = 0.876
# EPOCH 324 ... Validation Accuracy = 0.863
# EPOCH 325 ... Validation Accuracy = 0.867
# EPOCH 326 ... Validation Accuracy = 0.865
# EPOCH 327 ... Validation Accuracy = 0.863
# EPOCH 328 ... Validation Accuracy = 0.869
# EPOCH 329 ... Validation Accuracy = 0.869
# EPOCH 330 ... Validation Accuracy = 0.867
# EPOCH 331 ... Validation Accuracy = 0.873
# EPOCH 332 ... Validation Accuracy = 0.865
# EPOCH 333 ... Validation Accuracy = 0.872
# EPOCH 334 ... Validation Accuracy = 0.870
# EPOCH 335 ... Validation Accuracy = 0.873
# EPOCH 336 ... Validation Accuracy = 0.868
# EPOCH 337 ... Validation Accuracy = 0.865
# EPOCH 338 ... Validation Accuracy = 0.868
# EPOCH 339 ... Validation Accuracy = 0.869
# EPOCH 340 ... Validation Accuracy = 0.863
# EPOCH 341 ... Validation Accuracy = 0.870
# EPOCH 342 ... Validation Accuracy = 0.866
# EPOCH 343 ... Validation Accuracy = 0.863
# EPOCH 344 ... Validation Accuracy = 0.861
# EPOCH 345 ... Validation Accuracy = 0.869
# EPOCH 346 ... Validation Accuracy = 0.861
# EPOCH 347 ... Validation Accuracy = 0.868
# EPOCH 348 ... Validation Accuracy = 0.873
# EPOCH 349 ... Validation Accuracy = 0.868
# EPOCH 350 ... Validation Accuracy = 0.871
# EPOCH 351 ... Validation Accuracy = 0.872
# EPOCH 352 ... Validation Accuracy = 0.871
# EPOCH 353 ... Validation Accuracy = 0.871
# EPOCH 354 ... Validation Accuracy = 0.866
# EPOCH 355 ... Validation Accuracy = 0.870
# EPOCH 356 ... Validation Accuracy = 0.875
# EPOCH 357 ... Validation Accuracy = 0.875
# EPOCH 358 ... Validation Accuracy = 0.866
# EPOCH 359 ... Validation Accuracy = 0.867
# EPOCH 360 ... Validation Accuracy = 0.868
# EPOCH 361 ... Validation Accuracy = 0.874
# EPOCH 362 ... Validation Accuracy = 0.871
# EPOCH 363 ... Validation Accuracy = 0.865
# EPOCH 364 ... Validation Accuracy = 0.873
# EPOCH 365 ... Validation Accuracy = 0.871
# EPOCH 366 ... Validation Accuracy = 0.873
# EPOCH 367 ... Validation Accuracy = 0.872
# EPOCH 368 ... Validation Accuracy = 0.873
# EPOCH 369 ... Validation Accuracy = 0.871
# EPOCH 370 ... Validation Accuracy = 0.873
# EPOCH 371 ... Validation Accuracy = 0.871
# EPOCH 372 ... Validation Accuracy = 0.875
# EPOCH 373 ... Validation Accuracy = 0.868
# EPOCH 374 ... Validation Accuracy = 0.871
# EPOCH 375 ... Validation Accuracy = 0.868
# EPOCH 376 ... Validation Accuracy = 0.867
# EPOCH 377 ... Validation Accuracy = 0.864
# EPOCH 378 ... Validation Accuracy = 0.866
# EPOCH 379 ... Validation Accuracy = 0.867
# EPOCH 380 ... Validation Accuracy = 0.874
# EPOCH 381 ... Validation Accuracy = 0.866
# EPOCH 382 ... Validation Accuracy = 0.872
# EPOCH 383 ... Validation Accuracy = 0.871
# EPOCH 384 ... Validation Accuracy = 0.867
# EPOCH 385 ... Validation Accuracy = 0.871
# EPOCH 386 ... Validation Accuracy = 0.867
# EPOCH 387 ... Validation Accuracy = 0.868
# EPOCH 388 ... Validation Accuracy = 0.865
# EPOCH 389 ... Validation Accuracy = 0.871
# EPOCH 390 ... Validation Accuracy = 0.878
# EPOCH 391 ... Validation Accuracy = 0.872
# EPOCH 392 ... Validation Accuracy = 0.877
# EPOCH 393 ... Validation Accuracy = 0.870
# EPOCH 394 ... Validation Accuracy = 0.862
# EPOCH 395 ... Validation Accuracy = 0.868
# EPOCH 396 ... Validation Accuracy = 0.875
# EPOCH 397 ... Validation Accuracy = 0.873
# EPOCH 398 ... Validation Accuracy = 0.871
# EPOCH 399 ... Validation Accuracy = 0.874
# EPOCH 400 ... Validation Accuracy = 0.871
# EPOCH 401 ... Validation Accuracy = 0.873
# EPOCH 402 ... Validation Accuracy = 0.866
# EPOCH 403 ... Validation Accuracy = 0.874
# EPOCH 404 ... Validation Accuracy = 0.868
# EPOCH 405 ... Validation Accuracy = 0.873
# EPOCH 406 ... Validation Accuracy = 0.870
# EPOCH 407 ... Validation Accuracy = 0.867
# EPOCH 408 ... Validation Accuracy = 0.867
# EPOCH 409 ... Validation Accuracy = 0.862
# EPOCH 410 ... Validation Accuracy = 0.867
# EPOCH 411 ... Validation Accuracy = 0.865
# EPOCH 412 ... Validation Accuracy = 0.866
# EPOCH 413 ... Validation Accuracy = 0.871
# EPOCH 414 ... Validation Accuracy = 0.868
# EPOCH 415 ... Validation Accuracy = 0.872
# EPOCH 416 ... Validation Accuracy = 0.868
# EPOCH 417 ... Validation Accuracy = 0.872
# EPOCH 418 ... Validation Accuracy = 0.874
# EPOCH 419 ... Validation Accuracy = 0.866
# EPOCH 420 ... Validation Accuracy = 0.870
# EPOCH 421 ... Validation Accuracy = 0.871
# EPOCH 422 ... Validation Accuracy = 0.864
# EPOCH 423 ... Validation Accuracy = 0.869
# EPOCH 424 ... Validation Accuracy = 0.873
# EPOCH 425 ... Validation Accuracy = 0.871
# EPOCH 426 ... Validation Accuracy = 0.868
# EPOCH 427 ... Validation Accuracy = 0.875
# EPOCH 428 ... Validation Accuracy = 0.868
# EPOCH 429 ... Validation Accuracy = 0.864
# EPOCH 430 ... Validation Accuracy = 0.869
# EPOCH 431 ... Validation Accuracy = 0.864
# EPOCH 432 ... Validation Accuracy = 0.869
# EPOCH 433 ... Validation Accuracy = 0.870
# EPOCH 434 ... Validation Accuracy = 0.866
# EPOCH 435 ... Validation Accuracy = 0.870
# EPOCH 436 ... Validation Accuracy = 0.866
# EPOCH 437 ... Validation Accuracy = 0.863
# EPOCH 438 ... Validation Accuracy = 0.868
# EPOCH 439 ... Validation Accuracy = 0.866
# EPOCH 440 ... Validation Accuracy = 0.870
# EPOCH 441 ... Validation Accuracy = 0.863
# EPOCH 442 ... Validation Accuracy = 0.877
# EPOCH 443 ... Validation Accuracy = 0.871
# EPOCH 444 ... Validation Accuracy = 0.871
# EPOCH 445 ... Validation Accuracy = 0.873
# EPOCH 446 ... Validation Accuracy = 0.872
# EPOCH 447 ... Validation Accuracy = 0.876
# EPOCH 448 ... Validation Accuracy = 0.870
# EPOCH 449 ... Validation Accuracy = 0.876
# EPOCH 450 ... Validation Accuracy = 0.876
# EPOCH 451 ... Validation Accuracy = 0.868
# EPOCH 452 ... Validation Accuracy = 0.875
# EPOCH 453 ... Validation Accuracy = 0.869
# EPOCH 454 ... Validation Accuracy = 0.863
# EPOCH 455 ... Validation Accuracy = 0.872
# EPOCH 456 ... Validation Accuracy = 0.869
# EPOCH 457 ... Validation Accuracy = 0.866
# EPOCH 458 ... Validation Accuracy = 0.871
# EPOCH 459 ... Validation Accuracy = 0.868
# EPOCH 460 ... Validation Accuracy = 0.876
# EPOCH 461 ... Validation Accuracy = 0.866
# EPOCH 462 ... Validation Accuracy = 0.874
# EPOCH 463 ... Validation Accuracy = 0.877
# EPOCH 464 ... Validation Accuracy = 0.867
# EPOCH 465 ... Validation Accuracy = 0.866
# EPOCH 466 ... Validation Accuracy = 0.870
# EPOCH 467 ... Validation Accuracy = 0.870
# EPOCH 468 ... Validation Accuracy = 0.871
# EPOCH 469 ... Validation Accuracy = 0.869
# EPOCH 470 ... Validation Accuracy = 0.864
# EPOCH 471 ... Validation Accuracy = 0.869
# EPOCH 472 ... Validation Accuracy = 0.878
# EPOCH 473 ... Validation Accuracy = 0.869
# EPOCH 474 ... Validation Accuracy = 0.873
# EPOCH 475 ... Validation Accuracy = 0.870
# EPOCH 476 ... Validation Accuracy = 0.874
# EPOCH 477 ... Validation Accuracy = 0.872
# EPOCH 478 ... Validation Accuracy = 0.874
# EPOCH 479 ... Validation Accuracy = 0.869
# EPOCH 480 ... Validation Accuracy = 0.868
# EPOCH 481 ... Validation Accuracy = 0.869
# EPOCH 482 ... Validation Accuracy = 0.869
# EPOCH 483 ... Validation Accuracy = 0.869
# EPOCH 484 ... Validation Accuracy = 0.871
# EPOCH 485 ... Validation Accuracy = 0.864
# EPOCH 486 ... Validation Accuracy = 0.868
# EPOCH 487 ... Validation Accuracy = 0.865
# EPOCH 488 ... Validation Accuracy = 0.859
# EPOCH 489 ... Validation Accuracy = 0.872
# EPOCH 490 ... Validation Accuracy = 0.868
# EPOCH 491 ... Validation Accuracy = 0.863
# EPOCH 492 ... Validation Accuracy = 0.870
# EPOCH 493 ... Validation Accuracy = 0.876
# EPOCH 494 ... Validation Accuracy = 0.875
# EPOCH 495 ... Validation Accuracy = 0.875
# EPOCH 496 ... Validation Accuracy = 0.871
# EPOCH 497 ... Validation Accuracy = 0.872
# EPOCH 498 ... Validation Accuracy = 0.867
# EPOCH 499 ... Validation Accuracy = 0.866
# EPOCH 500 ... Validation Accuracy = 0.868
# Model saved

# %%
# 在最终测试集上的识别率
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))
    #saver.restore(sess, './lenet')

    #test_accuracy = evaluate(X_test, y_test)
    test_accuracy = evaluate(X_test , y_test)
    print("Test Accuracy = {:.3f}".format(test_accuracy))
# Out:
# INFO:tensorflow:Restoring parameters from ./lenet
# Test Accuracy = 0.869

# %% [markdown]
# ---
#
# ## Step 3: Test a Model on New Images
#
# To give yourself more insight into how your model is working, download at least five pictures of German traffic signs from the web and use your model to predict the traffic sign type.
#
# You may find `signnames.csv` useful as it contains mappings from the class id (integer) to the actual sign name.

# %% [markdown]
# ### Load and Output the Images

# %%
### Load the images and plot them here.
### Feel free to use as many code cells as needed.

# 以测试集中的索引号为5的图片为例
image = X_test[5:6].squeeze()


plt.figure(figsize = (1 , 1))
plt.imshow(image , cmap = "gray")
print(y_test[5:6])
# Out:
# [38]

# %% [markdown]
# ### Predict the Sign Type for Each Image

# %%
# 运行神经网络查看单张图片分类结果
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))
    output = evaluate(X_test[5:6] , y_test[5:6])
    print("Test Accuracy = {:.3f}".format(output))
    l = sess.run(logits , feed_dict = {x : X_test[5:6] , y : y_test[5:6]})
    print(l)
    l_mean = sess.run(tf.reduce_mean(l))
    print(l_mean)
    l = sess.run(tf.nn.softmax(l))
    print(l)
# Out:
# INFO:tensorflow:Restoring parameters from ./lenet
# Test Accuracy = 1.000
# [[-100.31588745  -75.42514038  -75.98116302  -76.76386261  -89.56222534
#    -28.73901939  -77.66815186  -80.97385406  -55.70073318  -91.83926392
#    -33.52455139  -99.90442657  -73.65011597  -31.08069038  -92.27519226
#    -61.52089691 -103.50132751  -77.78945923  -61.53006744 -112.10993958
#    -56.6259346  -114.01272583  -67.54780579  -36.38394547 -179.33506775
#    -60.23713303  -33.66836929 -146.76622009 -132.26428223  -91.47103119
#    -48.76330185  -66.52681732  -90.58194733  -70.71726227  -71.57926941
#    -78.32595062  -37.05526352  -77.30279541   51.39916992  -46.90766525
#    -38.1687355   -95.10671234  -60.47738647]]
# -73.2159
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   1.57190313e-35   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   1.31249134e-37   0.00000000e+00
#     0.00000000e+00   1.51165478e-36   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   1.13668152e-37   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#     0.00000000e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#     1.26227704e-39   0.00000000e+00   0.00000000e+00]]

# %% [markdown]
# ### Analyze Performance

# %%
### Calculate the accuracy for these 5 new images. 
### For example, if the model predicted 1 out of 5 signs correctly, it's 20% accurate on these new images.

X_test , y_test = shuffle(X_test , y_test)

#image = X_test[5]
#plt.figure(figsize = (1 , 1))
#plt.imshow(image , cmap = "gray")
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('.'))
    
    output = evaluate(X_test[0:5] , y_test[0:5])
    print(y_test[0:5])
    print("Test Accuracy = {:.3f}".format(output))
    l = sess.run(logits , feed_dict = {x : X_test[0:5] , y : y_test[0:5]})
    l = sess.run(tf.nn.softmax(l))
    la = sess.run(tf.nn.top_k(tf.constant(l), k=3))
    print(la)
# Out:
# INFO:tensorflow:Restoring parameters from ./lenet
# [13  9 13 33 11]
# Test Accuracy = 0.800
# TopKV2(values=array([[  1.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  1.00000000e+00,   5.53296374e-23,   6.55222506e-26],
#        [  1.00000000e+00,   6.43948195e-18,   7.92906225e-28],
#        [  1.00000000e+00,   4.71623529e-21,   2.02200767e-21],
#        [  9.25378025e-01,   7.01692402e-02,   2.16618925e-03]], dtype=float32), indices=array([[13,  0,  1],
#        [ 9, 10, 16],
#        [13, 15, 25],
#        [33, 14, 38],
#        [27, 41, 18]], dtype=int32))

# %% [markdown]
# ### Output Top 5 Softmax Probabilities For Each Image Found on the Web

# %% [markdown]
# For each of the new images, print out the model's softmax probabilities to show the **certainty** of the model's predictions (limit the output to the top 5 probabilities for each image). [`tf.nn.top_k`](https://www.tensorflow.org/versions/r0.12/api_docs/python/nn.html#top_k) could prove helpful here.
#
# The example below demonstrates how tf.nn.top_k can be used to find the top k predictions for each image.
#
# `tf.nn.top_k` will return the values and indices (class ids) of the top k predictions. So if k=3, for each sign, it'll return the 3 largest probabilities (out of a possible 43) and the correspoding class ids.
#
# Take this numpy array as an example. The values in the array represent predictions. The array contains softmax probabilities for five candidate images with six possible classes. `tf.nn.top_k` is used to choose the three classes with the highest probability:
#
# ```
# # (5, 6) array
# a = np.array([[ 0.24879643,  0.07032244,  0.12641572,  0.34763842,  0.07893497,
#          0.12789202],
#        [ 0.28086119,  0.27569815,  0.08594638,  0.0178669 ,  0.18063401,
#          0.15899337],
#        [ 0.26076848,  0.23664738,  0.08020603,  0.07001922,  0.1134371 ,
#          0.23892179],
#        [ 0.11943333,  0.29198961,  0.02605103,  0.26234032,  0.1351348 ,
#          0.16505091],
#        [ 0.09561176,  0.34396535,  0.0643941 ,  0.16240774,  0.24206137,
#          0.09155967]])
# ```
#
# Running it through `sess.run(tf.nn.top_k(tf.constant(a), k=3))` produces:
#
# ```
# TopKV2(values=array([[ 0.34763842,  0.24879643,  0.12789202],
#        [ 0.28086119,  0.27569815,  0.18063401],
#        [ 0.26076848,  0.23892179,  0.23664738],
#        [ 0.29198961,  0.26234032,  0.16505091],
#        [ 0.34396535,  0.24206137,  0.16240774]]), indices=array([[3, 0, 5],
#        [0, 1, 4],
#        [0, 5, 1],
#        [1, 3, 5],
#        [1, 4, 3]], dtype=int32))
# ```
#
# Looking just at the first row we get `[ 0.34763842,  0.24879643,  0.12789202]`, you can confirm these are the 3 largest probabilities in `a`. You'll also notice `[3, 0, 5]` are the corresponding indices.

# %%
### Print out the top five softmax probabilities for the predictions on the German traffic sign images found on the web. 
### Feel free to use as many code cells as needed.

# %% [markdown]
# ### Project Writeup
#
# Once you have completed the code implementation, document your results in a project writeup using this [template](https://github.com/udacity/CarND-Traffic-Sign-Classifier-Project/blob/master/writeup_template.md) as a guide. The writeup can be in a markdown or pdf file.

# %% [markdown]
# > **Note**: Once you have completed all of the code implementations and successfully answered each question above, you may finalize your work by exporting the iPython Notebook as an HTML document. You can do this by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.

# %% [markdown]
# ---
#
# ## Step 4 (Optional): Visualize the Neural Network's State with Test Images
#
#  This Section is not required to complete but acts as an additional excersise for understaning the output of a neural network's weights. While neural networks can be a great learning device they are often referred to as a black box. We can understand what the weights of a neural network look like better by plotting their feature maps. After successfully training your neural network you can see what it's feature maps look like by plotting the output of the network's weight layers in response to a test stimuli image. From these plotted feature maps, it's possible to see what characteristics of an image the network finds interesting. For a sign, maybe the inner network feature maps react with high activation to the sign's boundary outline or to the contrast in the sign's painted symbol.
#
#  Provided for you below is the function code that allows you to get the visualization output of any tensorflow weight layer you want. The inputs to the function should be a stimuli image, one used during training or a new one you provided, and then the tensorflow variable name that represents the layer's state during the training process, for instance if you wanted to see what the [LeNet lab's](https://classroom.udacity.com/nanodegrees/nd013/parts/fbf77062-5703-404e-b60c-95b78b2f3f9e/modules/6df7ae49-c61c-4bb2-a23e-6527e69209ec/lessons/601ae704-1035-4287-8b11-e2c2716217ad/concepts/d4aca031-508f-4e0b-b493-e7b706120f81) feature maps looked like for it's second convolutional layer you could enter conv2 as the tf_activation variable.
#
# For an example of what feature map outputs look like, check out NVIDIA's results in their paper [End-to-End Deep Learning for Self-Driving Cars](https://devblogs.nvidia.com/parallelforall/deep-learning-self-driving-cars/) in the section Visualization of internal CNN State. NVIDIA was able to show that their network's inner weights had high activations to road boundary lines by comparing feature maps from an image with a clear path to one without. Try experimenting with a similar test to show that your trained network's weights are looking for interesting features, whether it's looking at differences in feature maps from images with or without a sign, or even what feature maps look like in a trained network vs a completely untrained one on the same sign image.
#
# <figure>
#  <img src="visualize_cnn.png" width="380" alt="Combined Image" />
#  <figcaption>
#  <p></p>
#  <p style="text-align: center;"> Your output should look something like this (above)</p>
#  </figcaption>
# </figure>
#  <p></p>

# %%
### Visualize your network's feature maps here.
### Feel free to use as many code cells as needed.

# image_input: the test image being fed into the network to produce the feature maps
# tf_activation: should be a tf variable name used during your training procedure that represents the calculated state of a specific weight layer
# activation_min/max: can be used to view the activation contrast in more detail, by default matplot sets min and max to the actual min and max values of the output
# plt_num: used to plot out multiple different weight feature map sets on the same block, just extend the plt number for each new feature map entry

def outputFeatureMap(image_input, tf_activation, activation_min=-1, activation_max=-1 ,plt_num=1):
    # Here make sure to preprocess your image_input in a way your network expects
    # with size, normalization, ect if needed
    # image_input =
    # Note: x should be the same name as your network's tensorflow data placeholder variable
    # If you get an error tf_activation is not defined it may be having trouble accessing the variable from inside a function
    activation = tf_activation.eval(session=sess,feed_dict={x : image_input})
    featuremaps = activation.shape[3]
    plt.figure(plt_num, figsize=(15,15))
    for featuremap in range(featuremaps):
        plt.subplot(6,8, featuremap+1) # sets the number of feature maps to show on each row and column
        plt.title('FeatureMap ' + str(featuremap)) # displays the feature map number
        if activation_min != -1 & activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin =activation_min, vmax=activation_max, cmap="gray")
        elif activation_max != -1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmax=activation_max, cmap="gray")
        elif activation_min !=-1:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", vmin=activation_min, cmap="gray")
        else:
            plt.imshow(activation[0,:,:, featuremap], interpolation="nearest", cmap="gray")
